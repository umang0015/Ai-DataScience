# %% [markdown]
# <a href="https://colab.research.google.com/github/umang0015/Ai-DataScience/blob/main/22July.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d1  =pd.read_csv('https://raw.githubusercontent.com/Abeyaantrix2Internship/intern/main/Salary_Data.csv')
d1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
d1.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
d1.shape
# Out:
# (30, 2)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
d1.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x  = d1.YearsExperience
y = d1.Salary
print(x.shape,y.shape)
print(x.ndim, y.ndim)
# Out:
# (30,) (30,)
# 1 1

# %%
x1 = d1.iloc[: , 0:1]
y1 = d1.iloc[: , 1]
print(x1.shape, y1.shape)
print(x1.ndim , y1.ndim)
# Out:
# (30, 1) (30,)
# 2 1

# %%
x = d1[['YearsExperience']]
y = d1['Salary']

# %%
plt.scatter(x , y)
plt.xlabel("experience")
plt.ylabel("salary")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train , y_test = train_test_split(x,y, test_size= 0.25, random_state=10)
print(x_train.shape , x_test.shape)
print(y_train.shape , y_test.shape)
# Out:
# (22, 1) (8, 1)
# (22,) (8,)

# %%
x_train
# Out:
#     YearsExperience
# 12              4.0
# 1               1.3
# 19              6.0
# 14              4.5
# 18              5.9
# 6               3.0
# 11              4.0
# 23              8.2
# 24              8.7
# 28             10.3
# 22              7.9
# 10              3.9
# 26              9.5
# 29             10.5
# 8               3.2
# 25              9.0
# 16              5.1
# 17              5.3
# 0               1.1
# 15              4.9
# 4               2.2
# 9               3.7

# %%
x_test
# Out:
#     YearsExperience
# 20              6.8
# 7               3.2
# 5               2.9
# 2               1.5
# 3               2.0
# 21              7.1
# 13              4.1
# 27              9.6

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression() #model building
mod.fit(x_train ,y_train) #train the model
# Out:
# LinearRegression()

# %%
# y = mx +c
# salary = m* ye+c

# %%
# m = mod.coef_
# m

# %%
# c = mod.intercept_
# c

# %%
# salary = m*1.5+c
# salary

# %%
y_pre = mod.predict(x_test)
y_pre
# Out:
# array([ 90218.4402504 ,  56480.17500106,  53668.65289695,  40548.2164111 ,
#         45234.08658461,  93029.96235452,  64914.7413134 , 116459.31322211])

# %%
x_test
# Out:
#     YearsExperience
# 20              6.8
# 7               3.2
# 5               2.9
# 2               1.5
# 3               2.0
# 21              7.1
# 13              4.1
# 27              9.6

# %%
d1['y_pre'] = mod.predict(x)
d1
# Out:
#     YearsExperience    Salary          y_pre
# 0               1.1   39343.0   36799.520272
# 1               1.3   46205.0   38673.868342
# 2               1.5   37731.0   40548.216411
# 3               2.0   43525.0   45234.086585
# 4               2.2   39891.0   47108.434654
# 5               2.9   56642.0   53668.652897
# 6               3.0   60150.0   54605.826932
# 7               3.2   54445.0   56480.175001
# 8               3.2   64445.0   56480.175001
# 9               3.7   57189.0   61166.045175
# 10              3.9   63218.0   63040.393244
# 11              4.0   55794.0   63977.567279
# 12              4.0   56957.0   63977.567279
# 13              4.1   57081.0   64914.741313
# 14              4.5   61111.0   68663.437452
# 15              4.9   67938.0   72412.133591
# 16              5.1   66029.0   74286.481660
# 17              5.3   83088.0   76160.829730
# 18              5.9   81363.0   81783.873938
# 19              6.0   93940.0   82721.047973
# ...

# %%
mod.score(x_test , y_test)
# Out:
# 0.9760442172946989

# %%
mod.score(x_train , y_train)
# Out:
# 0.9487492719684324

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test , y_pre)
mae
# mse , rmse
# Out:
# 3494.4346288017096

# %%
df = pd.read_csv('/content/placement - placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
plt.figure(figsize=(8,6))
plt.hist(df['cgpa'] ,bins=20,edgecolor='black' , alpha=0.7,color='steelblue')

plt.axvline(df['cgpa'].mean() , color='red' , linestyle='--' , linewidth = 2,label=f'Mean: {df['cgpa'].mean():.2f}')


#labels and title
plt.xlabel('CGPA' , fontsize=12)
plt.ylabel('Frequency' , fontsize=12)
plt.title('Distribution of CGPA ' , fontsize=14, fontweight='bold')
plt.legend()
# add grid for better readability
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
X= df.iloc[:,0:1]
y= df.iloc[: , -1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train, Y_test = train_test_split(X , y, test_size = 0.2 ,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr =LinearRegression()

# %%
lr.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 20     91738.0
# 7      54445.0
# 5      56642.0
# 2      37731.0
# 3      43525.0
# 21     98273.0
# 13     57081.0
# 27    112635.0
# Name: Salary, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train , lr.predict(X_train) , color='red')
plt.xlabel('CGPA')
plt.ylabel('Package (in lpa)')
# Out:
# Text(0, 0.5, 'Package (in lpa)')

# %%
m  = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx+b
m * 8.58 +b
# Out:
# array([3.89111601])

# %%
m * 9.5 +b
# Out:
# array([4.40443183])

# %%
m * 10.0 + b
# Out:
# array([4.68340781])

# %%
# MAE < MSE < RMSE
